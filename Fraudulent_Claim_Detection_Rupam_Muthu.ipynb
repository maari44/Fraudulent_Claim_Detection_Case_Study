# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/My Drive/Assignments/Fraud_Claim_Detection/insurance_claims.csv'
df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
# Check at the first few entries
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft                ?      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                   NaN             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available         object
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                       object
# auto_model                      object
# auto_year                        int64
# fraud_reported                  object
# _c39                           float64
# dtype: object

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
before_updating = df['authorities_contacted'].value_counts()
df['authorities_contacted'] = df['authorities_contacted'].fillna(df['authorities_contacted'].mode()[0])
after_updating = df['authorities_contacted'].value_counts()
print("Before Updating the data with mode value :: ", before_updating)
print("After Updating the data with mode value :: ", after_updating)
# Out:
# Before Updating the data with mode value ::  authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64
# After Updating the data with mode value ::  authorities_contacted
# Police       383
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"\nColumn: {col}")
    print("#" *  50)

    print(df[col].value_counts(dropna=False))

    print(f"Total Unique value: {df[col].nunique()}")
    print("#" * 25)

    print("-" * 25)
    redundant = df[col].duplicated(keep=False)
    redundant_value = df[col][redundant].unique()

    if len(redundant_value) > 0:
        print(f"Redundant values:")
        for value in redundant_value:
            count = (df[col] == value).sum()
            if count > 1:
              print(f"No of times {value}: {count} occurrences")
    else:
        print("No redundant values found")
    print("-" * 50)
# Out:
# Column: months_as_customer
# ##################################################
# months_as_customer
# 194    8
# 285    7
# 254    7
# 101    7
# 128    7
#       ..
# 372    1
# 213    1
# 240    1
# 50     1
# 17     1
# Name: count, Length: 391, dtype: int64
# Total Unique value: 391
# #########################
# -------------------------
# Redundant values:
# No of times 328: 4 occurrences
# No of times 228: 4 occurrences
# No of times 134: 5 occurrences
# No of times 256: 4 occurrences
# No of times 137: 5 occurrences
# No of times 165: 5 occurrences
# No of times 27: 5 occurrences
# No of times 212: 4 occurrences
# No of times 235: 5 occurrences
# No of times 121: 4 occurrences
# No of times 180: 4 occurrences
# No of times 70: 4 occurrences
# No of times 140: 7 occurrences
# No of times 160: 4 occurrences
# No of times 196: 3 occurrences
# No of times 460: 2 occurrences
# No of times 217: 3 occurrences
# No of times 370: 2 occurrences
# No of times 237: 2 occurrences
# No of times 8: 3 occurrences
# No of times 257: 6 occurrences
# No of times 202: 2 occurrences
# No of times 224: 3 occurrences
# No of times 241: 5 occurrences
# No of times 64: 4 occurrences
# No of times 166: 4 occurrences
# No of times 155: 3 occurrences
# No of times 114: 2 occurrences
# No of times 149: 2 occurrences
# No of times 147: 6 occurrences
# No of times 289: 6 occurrences
# No of times 431: 2 occurrences
# No of times 199: 3 occurrences
# No of times 79: 2 occurrences
# No of times 116: 3 occurrences
# No of times 37: 3 occurrences
# No of times 106: 3 occurrences
# No of times 269: 5 occurrences
# No of times 265: 3 occurrences
# No of times 163: 6 occurrences
# No of times 175: 4 occurrences
# No of times 192: 3 occurrences
# No of times 91: 4 occurrences
# No of times 223: 3 occurrences
# No of times 195: 4 occurrences
# No of times 22: 4 occurrences
# No of times 439: 2 occurrences
# No of times 94: 3 occurrences
# No of times 11: 2 occurrences
# No of times 151: 3 occurrences
# No of times 154: 4 occurrences
# No of times 245: 6 occurrences
# No of times 119: 4 occurrences
# No of times 215: 4 occurrences
# No of times 295: 6 occurrences
# No of times 254: 7 occurrences
# No of times 107: 6 occurrences
# No of times 478: 2 occurrences
# No of times 128: 7 occurrences
# No of times 338: 3 occurrences
# No of times 271: 4 occurrences
# No of times 222: 6 occurrences
# No of times 120: 4 occurrences
# No of times 270: 4 occurrences
# No of times 194: 8 occurrences
# No of times 244: 3 occurrences
# No of times 78: 5 occurrences
# 41    45
# 34    44
# 31    42
# 38    42
# 30    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 44    32
# 36    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 55    14
# 49    14
# 25    14
# 50    13
# 53    13
# 61    10
# 24    10
# 54    10
# 51     9
# 60     9
# 56     8
# 58     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64
# Total Unique value: 46
# #########################
# -------------------------
# Redundant values:
# No of times 48: 25 occurrences
# No of times 42: 32 occurrences
# No of times 29: 35 occurrences
# No of times 41: 45 occurrences
# No of times 44: 32 occurrences
# No of times 39: 48 occurrences
# No of times 34: 44 occurrences
# No of times 37: 41 occurrences
# No of times 33: 39 occurrences
# No of times 61: 10 occurrences
# No of times 23: 7 occurrences
# No of times 38: 42 occurrences
# No of times 58: 8 occurrences
# No of times 26: 26 occurrences
# No of times 31: 42 occurrences
# No of times 62: 4 occurrences
# No of times 55: 14 occurrences
# No of times 40: 38 occurrences
# No of times 35: 32 occurrences
# No of times 43: 49 occurrences
# No of times 45: 26 occurrences
# No of times 25: 14 occurrences
# No of times 30: 42 occurrences
# No of times 28: 30 occurrences
# No of times 49: 14 occurrences
# No of times 54: 10 occurrences
# No of times 47: 24 occurrences
# No of times 59: 5 occurrences
# No of times 27: 24 occurrences
# No of times 56: 8 occurrences
# No of times 32: 38 occurrences
# No of times 36: 32 occurrences
# No of times 64: 2 occurrences
# No of times 60: 9 occurrences
# No of times 51: 9 occurrences
# No of times 46: 33 occurrences
# No of times 50: 13 occurrences
# No of times 57: 16 occurrences
# No of times 53: 13 occurrences
# No of times 24: 10 occurrences
# No of times 52: 4 occurrences
# No of times 21: 6 occurrences
# No of times 63: 2 occurrences
# --------------------------------------------------
#
# Column: policy_number
# ##################################################
# policy_number
# 556080    1
# 521585    1
# 342868    1
# 687698    1
# 227811    1
#          ..
# 842643    1
# 214618    1
# 543610    1
# 636550    1
# 485665    1
# Name: count, Length: 1000, dtype: int64
# Total Unique value: 1000
# #########################
# -------------------------
# No redundant values found
# --------------------------------------------------
#
# Column: policy_bind_date
# ##################################################
# policy_bind_date
# 1992-08-05    3
# 2006-01-01    3
# 1992-04-28    3
# 1996-07-07    2
# 2002-07-16    2
#              ..
# 1999-02-18    1
# 1997-10-30    1
# 1999-11-29    1
# 2013-07-07    1
# 1991-08-02    1
# Name: count, Length: 951, dtype: int64
# Total Unique value: 951
# #########################
# -------------------------
# Redundant values:
# No of times 1990-05-25: 2 occurrences
# No of times 2000-06-04: 2 occurrences
# No of times 1990-09-20: 2 occurrences
# No of times 2003-03-09: 2 occurrences
# No of times 1998-11-11: 2 occurrences
# No of times 2002-12-28: 2 occurrences
# No of times 1992-04-14: 2 occurrences
# No of times 1997-05-15: 2 occurrences
# No of times 1999-12-07: 2 occurrences
# No of times 1991-12-28: 2 occurrences
# No of times 2000-05-04: 2 occurrences
# No of times 1999-09-29: 2 occurrences
# No of times 2014-07-27: 2 occurrences
# No of times 2009-11-08: 2 occurrences
# No of times 1996-09-21: 2 occurrences
# No of times 1997-07-14: 2 occurrences
# No of times 1996-07-07: 2 occurrences
# No of times 2006-01-01: 3 occurrences
# No of times 2014-07-05: 2 occurrences
# No of times 2010-01-28: 2 occurrences
# No of times 2002-12-21: 2 occurrences
# No of times 1995-12-07: 2 occurrences
# No of times 2010-03-11: 2 occurrences
# No of times 1995-09-19: 2 occurrences
# No of times 1997-02-03: 2 occurrences
# No of times 2002-07-09: 2 occurrences
# No of times 2001-09-25: 2 occurrences
# No of times 2002-07-16: 2 occurrences
# No of times 1991-08-22: 2 occurrences
# No of times 2005-09-21: 2 occurrences
# No of times 1999-04-07: 2 occurrences
# No of times 2007-05-06: 2 occurrences
# No of times 1991-12-14: 2 occurrences
# No of times 2008-05-16: 2 occurrences
# No of times 1992-08-05: 3 occurrences
# No of times 1992-04-28: 3 occurrences
# No of times 2004-01-03: 2 occurrences
# No of times 2013-12-25: 2 occurrences
# No of times 1997-11-07: 2 occurrences
# No of times 2004-08-09: 2 occurrences
# No of times 1991-07-20: 2 occurrences
# No of times 1993-08-30: 2 occurrences
# No of times 1998-01-29: 2 occurrences
# No of times 1992-01-05: 2 occurrences
# No of times 1997-11-15: 2 occurrences
# No of times 1990-06-24: 2 occurrences
# --------------------------------------------------
#
# Column: policy_state
# ##################################################
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
# Total Unique value: 3
# #########################
# -------------------------
# Redundant values:
# No of times OH: 352 occurrences
# No of times IN: 310 occurrences
# No of times IL: 338 occurrences
# --------------------------------------------------
#
# Column: policy_csl
# ##################################################
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
# Total Unique value: 3
# #########################
# -------------------------
# Redundant values:
# No of times 250/500: 351 occurrences
# No of times 100/300: 349 occurrences
# No of times 500/1000: 300 occurrences
# --------------------------------------------------
#
# Column: policy_deductable
# ##################################################
# policy_deductable
# 1000    351
# 500     342
# 2000    307
# Name: count, dtype: int64
# Total Unique value: 3
# #########################
# -------------------------
# Redundant values:
# No of times 1000: 351 occurrences
# No of times 2000: 307 occurrences
# No of times 500: 342 occurrences
# --------------------------------------------------
#
# Column: policy_annual_premium
# ##################################################
# policy_annual_premium
# 1362.87    2
# 1073.83    2
# 1389.13    2
# 1524.45    2
# 1074.07    2
#           ..
# 1437.33    1
# 988.29     1
# 1238.89    1
# 1384.64    1
# 1554.64    1
# Name: count, Length: 991, dtype: int64
# Total Unique value: 991
# #########################
# -------------------------
# Redundant values:
# No of times 1215.36: 2 occurrences
# No of times 1374.22: 2 occurrences
# No of times 1558.29: 2 occurrences
# No of times 1073.83: 2 occurrences
# No of times 1362.87: 2 occurrences
# No of times 1074.07: 2 occurrences
# No of times 1281.25: 2 occurrences
# No of times 1524.45: 2 occurrences
# No of times 1389.13: 2 occurrences
# --------------------------------------------------
#
# Column: umbrella_limit
# ##################################################
# umbrella_limit
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
# Total Unique value: 11
# #########################
# -------------------------
# Redundant values:
# No of times 0: 798 occurrences
# No of times 5000000: 46 occurrences
# No of times 6000000: 57 occurrences
# No of times 4000000: 39 occurrences
# No of times 3000000: 12 occurrences
# No of times 8000000: 8 occurrences
# No of times 7000000: 29 occurrences
# No of times 9000000: 5 occurrences
# No of times 10000000: 2 occurrences
# No of times 2000000: 3 occurrences
# --------------------------------------------------
#
# Column: insured_zip
# ##################################################
# insured_zip
# 456602    2
# 469429    2
# 446895    2
# 431202    2
# 477695    2
#          ..
# 450339    1
# 476502    1
# 600561    1
# 600754    1
# 457535    1
# Name: count, Length: 995, dtype: int64
# Total Unique value: 995
# #########################
# -------------------------
# Redundant values:
# No of times 446895: 2 occurrences
# No of times 469429: 2 occurrences
# No of times 456602: 2 occurrences
# No of times 477695: 2 occurrences
# No of times 431202: 2 occurrences
# --------------------------------------------------
#
# Column: insured_sex
# ##################################################
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
# Total Unique value: 2
# #########################
# -------------------------
# Redundant values:
# No of times MALE: 463 occurrences
# No of times FEMALE: 537 occurrences
# --------------------------------------------------
#
# Column: insured_education_level
# ##################################################
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
# Total Unique value: 7
# #########################
# -------------------------
# Redundant values:
# No of times MD: 144 occurrences
# No of times PhD: 125 occurrences
# No of times Associate: 145 occurrences
# No of times Masters: 143 occurrences
# No of times High School: 160 occurrences
# No of times College: 122 occurrences
# No of times JD: 161 occurrences
# --------------------------------------------------
#
# Column: insured_occupation
# ##################################################
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# priv-house-serv      71
# other-service        71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
# Total Unique value: 14
# #########################
# -------------------------
# Redundant values:
# No of times craft-repair: 74 occurrences
# No of times machine-op-inspct: 93 occurrences
# No of times sales: 76 occurrences
# No of times armed-forces: 69 occurrences
# No of times tech-support: 78 occurrences
# No of times prof-specialty: 85 occurrences
# No of times other-service: 71 occurrences
# No of times priv-house-serv: 71 occurrences
# No of times exec-managerial: 76 occurrences
# No of times protective-serv: 63 occurrences
# No of times transport-moving: 72 occurrences
# No of times handlers-cleaners: 54 occurrences
# No of times adm-clerical: 65 occurrences
# No of times farming-fishing: 53 occurrences
# --------------------------------------------------
#
# Column: insured_hobbies
# ##################################################
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# camping           55
# golf              55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# base-jumping      49
# skydiving         49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
# Total Unique value: 20
# #########################
# -------------------------
# Redundant values:
# No of times sleeping: 41 occurrences
# No of times reading: 64 occurrences
# No of times board-games: 48 occurrences
# No of times bungie-jumping: 56 occurrences
# No of times base-jumping: 49 occurrences
# No of times golf: 55 occurrences
# No of times camping: 55 occurrences
# No of times dancing: 43 occurrences
# No of times skydiving: 49 occurrences
# No of times movies: 55 occurrences
# No of times hiking: 52 occurrences
# No of times yachting: 53 occurrences
# No of times paintball: 57 occurrences
# No of times chess: 46 occurrences
# No of times kayaking: 54 occurrences
# No of times polo: 47 occurrences
# No of times basketball: 34 occurrences
# No of times video-games: 50 occurrences
# No of times cross-fit: 35 occurrences
# No of times exercise: 57 occurrences
# --------------------------------------------------
#
# Column: insured_relationship
# ##################################################
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
# Total Unique value: 6
# #########################
# -------------------------
# Redundant values:
# No of times husband: 170 occurrences
# No of times other-relative: 177 occurrences
# No of times own-child: 183 occurrences
# No of times unmarried: 141 occurrences
# No of times wife: 155 occurrences
# No of times not-in-family: 174 occurrences
# --------------------------------------------------
#
# Column: capital-gains
# ##################################################
# capital-gains
# 0        508
# 46300      5
# 68500      4
# 51500      4
# 67800      3
#         ...
# 30800      1
# 42300      1
# 12800      1
# 69900      1
# 50300      1
# Name: count, Length: 338, dtype: int64
# Total Unique value: 338
# #########################
# -------------------------
# Redundant values:
# No of times 53300: 2 occurrences
# No of times 0: 508 occurrences
# No of times 35100: 3 occurrences
# No of times 48900: 3 occurrences
# No of times 66000: 2 occurrences
# No of times 38400: 2 occurrences
# No of times 52800: 3 occurrences
# No of times 41300: 2 occurrences
# No of times 55700: 2 occurrences
# No of times 63600: 3 occurrences
# No of times 53500: 2 occurrences
# No of times 45500: 3 occurrences
# No of times 46700: 3 occurrences
# No of times 53200: 3 occurrences
# No of times 51400: 3 occurrences
# No of times 65700: 2 occurrences
# No of times 48500: 2 occurrences
# No of times 49700: 3 occurrences
# No of times 36400: 2 occurrences
# No of times 35300: 2 occurrences
# No of times 47600: 3 occurrences
# No of times 36100: 2 occurrences
# No of times 36900: 3 occurrences
# No of times 62400: 2 occurrences
# No of times 35700: 2 occurrences
# No of times 59600: 3 occurrences
# No of times 37800: 2 occurrences
# No of times 52700: 2 occurrences
# No of times 55200: 2 occurrences
# No of times 52600: 3 occurrences
# No of times 34400: 2 occurrences
# No of times 51100: 3 occurrences
# No of times 47200: 2 occurrences
# No of times 40700: 2 occurrences
# No of times 57900: 2 occurrences
# No of times 45300: 2 occurrences
# No of times 46300: 5 occurrences
# No of times 58600: 2 occurrences
# No of times 54100: 2 occurrences
# No of times 58100: 2 occurrences
# No of times 62500: 2 occurrences
# No of times 39600: 2 occurrences
# No of times 71400: 2 occurrences
# No of times 51000: 2 occurrences
# No of times 25000: 2 occurrences
# No of times 68500: 4 occurrences
# No of times 42900: 3 occurrences
# No of times 29300: 3 occurrences
# No of times 63100: 3 occurrences
# No of times 66400: 2 occurrences
# No of times 59900: 2 occurrences
# No of times 62200: 2 occurrences
# No of times 24000: 2 occurrences
# No of times 53000: 2 occurrences
# No of times 65600: 2 occurrences
# No of times 39900: 2 occurrences
# No of times 60300: 2 occurrences
# No of times 47500: 2 occurrences
# No of times 44400: 2 occurrences
# No of times 51500: 4 occurrences
# No of times 52100: 2 occurrences
# No of times 57800: 2 occurrences
# No of times 55400: 2 occurrences
# No of times 49900: 3 occurrences
# No of times 53100: 2 occurrences
# No of times 55600: 3 occurrences
# No of times 47400: 2 occurrences
# No of times 26900: 2 occurrences
# No of times 64200: 2 occurrences
# No of times 44000: 3 occurrences
# No of times 61600: 2 occurrences
# No of times 58500: 3 occurrences
# No of times 35400: 2 occurrences
# No of times 75800: 3 occurrences
# No of times 67400: 2 occurrences
# No of times 46400: 2 occurrences
# No of times 56700: 3 occurrences
# No of times 47900: 2 occurrences
# No of times 30400: 2 occurrences
# No of times 69400: 2 occurrences
# No of times 45700: 3 occurrences
# No of times 64800: 2 occurrences
# No of times 61400: 2 occurrences
# No of times 63900: 2 occurrences
# No of times 44900: 2 occurrences
# No of times 54600: 2 occurrences
# No of times 37900: 3 occurrences
# No of times 70300: 2 occurrences
# No of times 42800: 2 occurrences
# No of times 46500: 2 occurrences
# No of times 38000: 2 occurrences
# No of times 51700: 3 occurrences
# No of times 38600: 3 occurrences
# No of times 54500: 2 occurrences
# No of times 49600: 2 occurrences
# No of times 43700: 3 occurrences
# No of times 52200: 2 occurrences
# No of times 55300: 2 occurrences
# No of times 33500: 2 occurrences
# No of times 55100: 2 occurrences
# No of times 69500: 2 occurrences
# No of times 50400: 2 occurrences
# No of times 53800: 2 occurrences
# No of times 50700: 2 occurrences
# No of times 42200: 2 occurrences
# No of times 44500: 2 occurrences
# No of times 57500: 2 occurrences
# No of times 39300: 2 occurrences
# No of times 51300: 2 occurrences
# No of times 57100: 2 occurrences
# No of times 67800: 3 occurrences
# No of times 46100: 2 occurrences
# No of times 46800: 2 occurrences
# No of times 35000: 2 occurrences
# No of times 32500: 2 occurrences
# No of times 25800: 2 occurrences
# No of times 61100: 2 occurrences
# No of times 70900: 2 occurrences
# No of times 73700: 2 occurrences
# No of times 59400: 2 occurrences
# --------------------------------------------------
#
# Column: capital-loss
# ##################################################
# capital-loss
#  0        475
# -53700      5
# -50300      5
# -31700      5
# -61400      4
#          ...
# -65500      1
# -15900      1
# -61200      1
# -32200      1
# -82100      1
# Name: count, Length: 354, dtype: int64
# Total Unique value: 354
# #########################
# -------------------------
# Redundant values:
# No of times 0: 475 occurrences
# No of times -62400: 3 occurrences
# No of times -46000: 2 occurrences
# No of times -77000: 2 occurrences
# No of times -39300: 3 occurrences
# No of times -51000: 4 occurrences
# No of times -32800: 4 occurrences
# No of times -68200: 3 occurrences
# No of times -30200: 2 occurrences
# No of times -55600: 3 occurrences
# No of times -64000: 2 occurrences
# No of times -49200: 4 occurrences
# No of times -67400: 3 occurrences
# No of times -60200: 2 occurrences
# No of times -28700: 2 occurrences
# No of times -46500: 2 occurrences
# No of times -55000: 2 occurrences
# No of times -45800: 3 occurrences
# No of times -49500: 3 occurrences
# No of times -49000: 3 occurrences
# No of times -66200: 3 occurrences
# No of times -51500: 3 occurrences
# No of times -50000: 3 occurrences
# No of times -50300: 5 occurrences
# No of times -42900: 2 occurrences
# No of times -45000: 2 occurrences
# No of times -40600: 2 occurrences
# No of times -44200: 2 occurrences
# No of times -78600: 3 occurrences
# No of times -20800: 2 occurrences
# No of times -58400: 3 occurrences
# No of times -71700: 2 occurrences
# No of times -31700: 5 occurrences
# No of times -58100: 2 occurrences
# No of times -24300: 2 occurrences
# No of times -56400: 2 occurrences
# No of times -57000: 2 occurrences
# No of times -56800: 2 occurrences
# No of times -53700: 5 occurrences
# No of times -32100: 2 occurrences
# No of times -65600: 2 occurrences
# No of times -56200: 3 occurrences
# No of times -57100: 2 occurrences
# No of times -44600: 2 occurrences
# No of times -44500: 3 occurrences
# No of times -54000: 2 occurrences
# No of times -31400: 4 occurrences
# No of times -51100: 2 occurrences
# No of times -45100: 3 occurrences
# No of times -58900: 3 occurrences
# No of times -22300: 2 occurrences
# No of times -51300: 2 occurrences
# No of times -57700: 2 occurrences
# No of times -57500: 2 occurrences
# No of times -36700: 2 occurrences
# No of times -39700: 2 occurrences
# No of times -72500: 2 occurrences
# No of times -67800: 3 occurrences
# No of times -32500: 2 occurrences
# No of times -53800: 4 occurrences
# No of times -70300: 2 occurrences
# No of times -41400: 3 occurrences
# No of times -52600: 2 occurrences
# No of times -47100: 2 occurrences
# No of times -33100: 2 occurrences
# No of times -46900: 3 occurrences
# No of times -61000: 3 occurrences
# No of times -53300: 3 occurrences
# No of times -49400: 3 occurrences
# No of times -40900: 2 occurrences
# No of times -33300: 3 occurrences
# No of times -32300: 2 occurrences
# No of times -15700: 2 occurrences
# No of times -51800: 3 occurrences
# No of times -54600: 2 occurrences
# No of times -35200: 2 occurrences
# No of times -63900: 2 occurrences
# No of times -42100: 2 occurrences
# No of times -48700: 2 occurrences
# No of times -43800: 2 occurrences
# No of times -73400: 2 occurrences
# No of times -42600: 2 occurrences
# No of times -54300: 2 occurrences
# No of times -55300: 2 occurrences
# No of times -37900: 2 occurrences
# No of times -54100: 2 occurrences
# No of times -62500: 2 occurrences
# No of times -45300: 4 occurrences
# No of times -36600: 2 occurrences
# No of times -42700: 3 occurrences
# No of times -28800: 2 occurrences
# No of times -66300: 2 occurrences
# No of times -43700: 2 occurrences
# No of times -56900: 2 occurrences
# No of times -54700: 2 occurrences
# No of times -51200: 2 occurrences
# No of times -43600: 2 occurrences
# No of times -41200: 3 occurrences
# No of times -60600: 2 occurrences
# No of times -30400: 2 occurrences
# No of times -39100: 2 occurrences
# No of times -65300: 2 occurrences
# No of times -55800: 2 occurrences
# No of times -49900: 2 occurrences
# No of times -61400: 4 occurrences
# No of times -48500: 2 occurrences
# No of times -57600: 2 occurrences
# No of times -44000: 2 occurrences
# No of times -61500: 2 occurrences
# No of times -49300: 3 occurrences
# No of times -64500: 3 occurrences
# No of times -44800: 2 occurrences
# No of times -59500: 2 occurrences
# No of times -44400: 2 occurrences
# No of times -52100: 2 occurrences
# No of times -63700: 2 occurrences
# No of times -72100: 2 occurrences
# No of times -48800: 3 occurrences
# No of times -49700: 2 occurrences
# No of times -70900: 2 occurrences
# --------------------------------------------------
#
# No of times 2015-02-08: 17 occurrences
# No of times 2015-02-23: 19 occurrences
# No of times 2015-03-01: 12 occurrences
# No of times 2015-01-14: 19 occurrences
# No of times 2015-02-19: 10 occurrences
# No of times 2015-02-09: 13 occurrences
# No of times 2015-01-26: 11 occurrences
# No of times 2015-01-23: 13 occurrences
# No of times 2015-01-31: 20 occurrences
# No of times 2015-02-03: 13 occurrences
# No of times 2015-02-01: 18 occurrences
# No of times 2015-02-05: 16 occurrences
# No of times 2015-02-25: 18 occurrences
# No of times 2015-02-16: 16 occurrences
# No of times 2015-02-13: 16 occurrences
# No of times 2015-02-04: 24 occurrences
# No of times 2015-02-07: 10 occurrences
# No of times 2015-01-04: 12 occurrences
# --------------------------------------------------
#
# Column: incident_type
# ##################################################
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
# Total Unique value: 4
# #########################
# -------------------------
# Redundant values:
# No of times Single Vehicle Collision: 403 occurrences
# No of times Vehicle Theft: 94 occurrences
# No of times Multi-vehicle Collision: 419 occurrences
# No of times Parked Car: 84 occurrences
# --------------------------------------------------
#
# Column: collision_type
# ##################################################
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
# Total Unique value: 4
# #########################
# -------------------------
# Redundant values:
# No of times Side Collision: 276 occurrences
# No of times ?: 178 occurrences
# No of times Rear Collision: 292 occurrences
# No of times Front Collision: 254 occurrences
# --------------------------------------------------
#
# Column: incident_severity
# ##################################################
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
# Total Unique value: 4
# #########################
# -------------------------
# Redundant values:
# No of times Major Damage: 276 occurrences
# No of times Minor Damage: 354 occurrences
# No of times Total Loss: 280 occurrences
# No of times Trivial Damage: 90 occurrences
# --------------------------------------------------
#
# Column: authorities_contacted
# ##################################################
# authorities_contacted
# Police       383
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64
# Total Unique value: 4
# #########################
# -------------------------
# Redundant values:
# No of times Police: 383 occurrences
# No of times Fire: 223 occurrences
# No of times Other: 198 occurrences
# No of times Ambulance: 196 occurrences
# --------------------------------------------------
#
# Column: incident_state
# ##################################################
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
# Total Unique value: 7
# #########################
# -------------------------
# Redundant values:
# No of times SC: 248 occurrences
# No of times VA: 110 occurrences
# No of times NY: 262 occurrences
# No of times OH: 23 occurrences
# No of times WV: 217 occurrences
# No of times NC: 110 occurrences
# No of times PA: 30 occurrences
# --------------------------------------------------
#
# Column: incident_city
# ##################################################
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
# Total Unique value: 7
# #########################
# -------------------------
# Redundant values:
# No of times Columbus: 149 occurrences
# No of times Riverwood: 134 occurrences
# No of times Arlington: 152 occurrences
# No of times Springfield: 157 occurrences
# No of times Hillsdale: 141 occurrences
# No of times Northbend: 145 occurrences
# No of times Northbrook: 122 occurrences
# --------------------------------------------------
#
# Column: incident_location
# ##################################################
# incident_location
# 1416 Cherokee Ridge    1
# 9935 4th Drive         1
# 6608 MLK Hwy           1
# 7121 Francis Lane      1
# 6956 Maple Drive       1
#                       ..
# 6655 5th Drive         1
# 5971 5th Hwy           1
# 1558 1st Ridge         1
# 3066 Francis Ave       1
# 4872 Rock Ridge        1
# Name: count, Length: 1000, dtype: int64
# Total Unique value: 1000
# #########################
# -------------------------
# No redundant values found
# --------------------------------------------------
#
# Column: incident_hour_of_the_day
# ##################################################
# incident_hour_of_the_day
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 4     46
# 10    46
# 13    46
# 6     44
# 14    43
# 9     43
# 21    42
# 18    41
# 7     40
# 12    40
# 19    40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: count, dtype: int64
# Total Unique value: 24
# #########################
# -------------------------
# Redundant values:
# No of times 5: 33 occurrences
# No of times 8: 36 occurrences
# No of times 7: 40 occurrences
# No of times 20: 34 occurrences
# No of times 19: 40 occurrences
# No of times 0: 52 occurrences
# No of times 23: 51 occurrences
# No of times 21: 42 occurrences
# No of times 14: 43 occurrences
# No of times 22: 38 occurrences
# No of times 9: 43 occurrences
# No of times 12: 40 occurrences
# No of times 15: 39 occurrences
# No of times 6: 44 occurrences
# No of times 16: 49 occurrences
# No of times 4: 46 occurrences
# No of times 10: 46 occurrences
# No of times 1: 29 occurrences
# No of times 17: 54 occurrences
# No of times 3: 53 occurrences
# No of times 11: 30 occurrences
# No of times 13: 46 occurrences
# No of times 18: 41 occurrences
# No of times 2: 31 occurrences
# --------------------------------------------------
#
# Column: number_of_vehicles_involved
# ##################################################
# number_of_vehicles_involved
# 1    581
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
# Total Unique value: 4
# #########################
# -------------------------
# Redundant values:
# No of times 1: 581 occurrences
# No of times 3: 358 occurrences
# No of times 4: 31 occurrences
# No of times 2: 30 occurrences
# --------------------------------------------------
#
# Column: property_damage
# ##################################################
# property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
# Total Unique value: 3
# #########################
# -------------------------
# Redundant values:
# No of times YES: 302 occurrences
# No of times ?: 360 occurrences
# No of times NO: 338 occurrences
# --------------------------------------------------
#
# Column: bodily_injuries
# ##################################################
# bodily_injuries
# 0    340
# 2    332
# 1    328
# Name: count, dtype: int64
# Total Unique value: 3
# #########################
# -------------------------
# Redundant values:
# No of times 1: 328 occurrences
# No of times 0: 340 occurrences
# No of times 2: 332 occurrences
# --------------------------------------------------
#
# Column: witnesses
# ##################################################
# witnesses
# 1    258
# 2    250
# 0    249
# 3    243
# Name: count, dtype: int64
# Total Unique value: 4
# #########################
# -------------------------
# Redundant values:
# No of times 2: 250 occurrences
# No of times 0: 249 occurrences
# No of times 3: 243 occurrences
# No of times 1: 258 occurrences
# --------------------------------------------------
#
# Column: police_report_available
# ##################################################
# police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64
# Total Unique value: 3
# #########################
# -------------------------
# Redundant values:
# No of times YES: 314 occurrences
# No of times ?: 343 occurrences
# No of times NO: 343 occurrences
# --------------------------------------------------
#
# Column: total_claim_amount
# ##################################################
# total_claim_amount
# 59400    5
# 44200    4
# 3190     4
# 75400    4
# 70400    4
#         ..
# 4800     1
# 80080    1
# 7590     1
# 45180    1
# 89520    1
# Name: count, Length: 763, dtype: int64
# Total Unique value: 763
# #########################
# -------------------------
# Redundant values:
# No of times 71610: 2 occurrences
# No of times 34650: 2 occurrences
# No of times 6500: 2 occurrences
# No of times 64100: 3 occurrences
# No of times 78650: 2 occurrences
# No of times 46200: 3 occurrences
# No of times 63120: 2 occurrences
# No of times 77880: 3 occurrences
# No of times 72930: 2 occurrences
# No of times 77110: 2 occurrences
# No of times 64800: 3 occurrences
# No of times 53100: 3 occurrences
# No of times 60200: 2 occurrences
# No of times 60170: 2 occurrences
# No of times 97080: 2 occurrences
# No of times 62800: 2 occurrences
# No of times 7260: 2 occurrences
# No of times 4300: 2 occurrences
# No of times 2640: 4 occurrences
# No of times 56430: 2 occurrences
# No of times 62920: 3 occurrences
# No of times 69480: 3 occurrences
# No of times 44280: 2 occurrences
# No of times 51210: 2 occurrences
# No of times 50800: 3 occurrences
# No of times 6600: 3 occurrences
# No of times 6490: 2 occurrences
# No of times 60940: 2 occurrences
# No of times 58300: 3 occurrences
# No of times 4700: 3 occurrences
# No of times 66950: 2 occurrences
# No of times 5900: 3 occurrences
# No of times 6930: 2 occurrences
# No of times 5400: 2 occurrences
# No of times 5600: 2 occurrences
# No of times 52800: 3 occurrences
# No of times 4320: 4 occurrences
# No of times 79800: 3 occurrences
# No of times 74200: 3 occurrences
# No of times 74700: 3 occurrences
# No of times 81070: 2 occurrences
# No of times 7080: 3 occurrences
# No of times 47700: 2 occurrences
# No of times 70400: 4 occurrences
# No of times 69300: 3 occurrences
# No of times 76560: 2 occurrences
# No of times 55440: 2 occurrences
# No of times 3960: 2 occurrences
# No of times 61500: 2 occurrences
# No of times 46800: 2 occurrences
# No of times 76120: 2 occurrences
# No of times 52030: 2 occurrences
# No of times 5170: 2 occurrences
# No of times 64000: 2 occurrences
# No of times 47300: 2 occurrences
# No of times 63240: 2 occurrences
# No of times 54240: 2 occurrences
# No of times 6160: 2 occurrences
# No of times 61380: 2 occurrences
# No of times 5940: 4 occurrences
# No of times 53600: 2 occurrences
# No of times 62590: 2 occurrences
# No of times 4950: 3 occurrences
# No of times 5500: 2 occurrences
# No of times 59400: 5 occurrences
# No of times 64350: 3 occurrences
# No of times 54400: 2 occurrences
# No of times 6120: 2 occurrences
# No of times 53460: 3 occurrences
# No of times 7200: 2 occurrences
# No of times 70290: 4 occurrences
# No of times 60190: 2 occurrences
# No of times 57060: 2 occurrences
# No of times 59040: 2 occurrences
# No of times 53680: 3 occurrences
# No of times 6300: 2 occurrences
# No of times 3200: 2 occurrences
# No of times 75400: 4 occurrences
# No of times 7480: 2 occurrences
# No of times 63250: 2 occurrences
# No of times 61490: 3 occurrences
# No of times 6890: 2 occurrences
# No of times 53280: 3 occurrences
# No of times 41490: 2 occurrences
# No of times 3080: 2 occurrences
# No of times 64080: 3 occurrences
# No of times 70900: 2 occurrences
# No of times 6820: 3 occurrences
# No of times 79560: 2 occurrences
# No of times 6400: 3 occurrences
# No of times 66780: 2 occurrences
# No of times 52700: 2 occurrences
# No of times 53400: 3 occurrences
# No of times 77100: 2 occurrences
# No of times 3300: 2 occurrences
# No of times 77440: 3 occurrences
# No of times 84500: 2 occurrences
# No of times 63600: 2 occurrences
# No of times 66550: 2 occurrences
# No of times 65780: 2 occurrences
# No of times 3190: 4 occurrences
# No of times 50380: 2 occurrences
# No of times 57860: 2 occurrences
# No of times 52200: 2 occurrences
# No of times 68760: 2 occurrences
# No of times 65520: 2 occurrences
# No of times 42700: 2 occurrences
# No of times 3600: 2 occurrences
# No of times 48950: 2 occurrences
# No of times 74360: 2 occurrences
# No of times 66200: 2 occurrences
# No of times 44200: 4 occurrences
# No of times 59670: 2 occurrences
# No of times 5000: 3 occurrences
# No of times 60600: 4 occurrences
# No of times 54340: 2 occurrences
# No of times 58500: 4 occurrences
# No of times 57330: 2 occurrences
# No of times 49400: 2 occurrences
# No of times 68750: 2 occurrences
# No of times 56000: 2 occurrences
# No of times 4290: 2 occurrences
# No of times 60750: 2 occurrences
# No of times 79500: 2 occurrences
# No of times 84590: 3 occurrences
# No of times 62900: 2 occurrences
# No of times 50000: 2 occurrences
# No of times 59070: 2 occurrences
# No of times 63300: 2 occurrences
# No of times 4680: 2 occurrences
# No of times 63580: 2 occurrences
# No of times 42900: 2 occurrences
# No of times 3840: 2 occurrences
# No of times 77000: 2 occurrences
# No of times 2700: 2 occurrences
# No of times 74140: 2 occurrences
# No of times 83160: 2 occurrences
# No of times 76400: 2 occurrences
# No of times 42500: 2 occurrences
# No of times 4620: 3 occurrences
# No of times 57700: 3 occurrences
# No of times 79090: 2 occurrences
# No of times 69400: 2 occurrences
# No of times 55000: 3 occurrences
# No of times 64200: 2 occurrences
# No of times 67320: 2 occurrences
# No of times 61740: 2 occurrences
# No of times 4900: 2 occurrences
# No of times 6050: 2 occurrences
# No of times 60500: 2 occurrences
# No of times 5060: 3 occurrences
# No of times 48360: 2 occurrences
# No of times 3900: 2 occurrences
# No of times 33480: 2 occurrences
# No of times 4200: 2 occurrences
# No of times 60480: 2 occurrences
# No of times 56160: 3 occurrences
# No of times 51390: 2 occurrences
# No of times 55400: 2 occurrences
# No of times 5830: 2 occurrences
# No of times 64400: 2 occurrences
# No of times 86130: 2 occurrences
# No of times 82170: 2 occurrences
# No of times 66660: 2 occurrences
# No of times 55200: 3 occurrences
# No of times 63900: 2 occurrences
# No of times 68200: 2 occurrences
# No of times 57900: 2 occurrences
# No of times 30700: 2 occurrences
# No of times 48000: 2 occurrences
# No of times 45100: 2 occurrences
# No of times 61050: 2 occurrences
# No of times 67800: 2 occurrences
# No of times 5590: 2 occurrences
# No of times 56320: 2 occurrences
# No of times 57200: 2 occurrences
# No of times 46980: 2 occurrences
# --------------------------------------------------
#
# Column: injury_claim
# ##################################################
# injury_claim
# 0        25
# 640       7
# 480       7
# 5540      5
# 860       5
#          ..
# 14560     1
# 7980      1
# 3880      1
# 13200     1
# 6790      1
# Name: count, Length: 638, dtype: int64
# Total Unique value: 638
# #########################
# -------------------------
# No of times 6290: 2 occurrences
# No of times 5000: 2 occurrences
# No of times 5370: 2 occurrences
# No of times 6330: 4 occurrences
# No of times 11600: 2 occurrences
# No of times 13380: 2 occurrences
# No of times 5930: 2 occurrences
# No of times 12320: 2 occurrences
# No of times 11560: 2 occurrences
# No of times 6140: 3 occurrences
# No of times 13480: 2 occurrences
# No of times 7640: 2 occurrences
# No of times 4250: 2 occurrences
# No of times 840: 4 occurrences
# No of times 9760: 2 occurrences
# No of times 8410: 2 occurrences
# No of times 5770: 3 occurrences
# No of times 5430: 2 occurrences
# No of times 5380: 2 occurrences
# No of times 10000: 5 occurrences
# No of times 510: 2 occurrences
# No of times 6510: 2 occurrences
# No of times 1000: 2 occurrences
# No of times 12100: 2 occurrences
# No of times 6600: 2 occurrences
# No of times 14140: 2 occurrences
# No of times 4060: 2 occurrences
# No of times 400: 2 occurrences
# No of times 14360: 2 occurrences
# No of times 6070: 2 occurrences
# No of times 1100: 2 occurrences
# No of times 4940: 2 occurrences
# No of times 5660: 2 occurrences
# No of times 920: 3 occurrences
# No of times 8060: 2 occurrences
# No of times 5940: 2 occurrences
# No of times 10700: 2 occurrences
# No of times 4040: 2 occurrences
# No of times 3720: 2 occurrences
# No of times 440: 2 occurrences
# No of times 4270: 2 occurrences
# No of times 12480: 2 occurrences
# No of times 1200: 2 occurrences
# No of times 7560: 3 occurrences
# No of times 6610: 2 occurrences
# No of times 6440: 2 occurrences
# No of times 7470: 3 occurrences
# No of times 6060: 3 occurrences
# No of times 15120: 2 occurrences
# No of times 5220: 3 occurrences
# No of times 10600: 2 occurrences
# No of times 560: 2 occurrences
# No of times 1080: 2 occurrences
# No of times 600: 2 occurrences
# No of times 6780: 2 occurrences
# --------------------------------------------------
#
# Column: vehicle_claim
# ##################################################
# vehicle_claim
# 5040     7
# 3360     6
# 4720     5
# 44800    5
# 3600     5
#         ..
# 42390    1
# 79560    1
# 32900    1
# 22160    1
# 32830    1
# Name: count, Length: 726, dtype: int64
# Total Unique value: 726
# #########################
# -------------------------
# Redundant values:
# No of times 52080: 5 occurrences
# No of times 23100: 2 occurrences
# No of times 4550: 2 occurrences
# No of times 51280: 2 occurrences
# No of times 50050: 2 occurrences
# No of times 63280: 2 occurrences
# No of times 5040: 7 occurrences
# No of times 33600: 5 occurrences
# No of times 42080: 2 occurrences
# No of times 56640: 2 occurrences
# No of times 53040: 2 occurrences
# No of times 41920: 2 occurrences
# No of times 33110: 2 occurrences
# No of times 44000: 2 occurrences
# No of times 4160: 2 occurrences
# No of times 46560: 2 occurrences
# No of times 37170: 2 occurrences
# No of times 48160: 3 occurrences
# No of times 28000: 2 occurrences
# No of times 64720: 2 occurrences
# No of times 50240: 2 occurrences
# No of times 5280: 2 occurrences
# No of times 3440: 2 occurrences
# No of times 44870: 2 occurrences
# No of times 1680: 2 occurrences
# No of times 55230: 2 occurrences
# No of times 50160: 2 occurrences
# No of times 45760: 2 occurrences
# No of times 49840: 3 occurrences
# No of times 2580: 3 occurrences
# No of times 49680: 2 occurrences
# No of times 27090: 2 occurrences
# No of times 42840: 2 occurrences
# No of times 33880: 2 occurrences
# No of times 40040: 2 occurrences
# No of times 2320: 3 occurrences
# No of times 4960: 2 occurrences
# No of times 46320: 3 occurrences
# No of times 3500: 2 occurrences
# No of times 48510: 2 occurrences
# No of times 47320: 3 occurrences
# No of times 42420: 3 occurrences
# No of times 40950: 2 occurrences
# No of times 4480: 2 occurrences
# No of times 34580: 2 occurrences
# No of times 77670: 2 occurrences
# No of times 55440: 2 occurrences
# No of times 61520: 2 occurrences
# No of times 42480: 2 occurrences
# No of times 57440: 2 occurrences
# No of times 43620: 2 occurrences
# No of times 44030: 3 occurrences
# No of times 34860: 2 occurrences
# No of times 41510: 2 occurrences
# No of times 41160: 2 occurrences
# No of times 2560: 2 occurrences
# No of times 1440: 2 occurrences
# No of times 2100: 3 occurrences
# No of times 46240: 2 occurrences
# No of times 49120: 2 occurrences
# No of times 53480: 2 occurrences
# No of times 48020: 3 occurrences
# No of times 42770: 2 occurrences
# No of times 2940: 4 occurrences
# No of times 39040: 3 occurrences
# No of times 58870: 2 occurrences
# No of times 33180: 2 occurrences
# No of times 3570: 2 occurrences
# No of times 4000: 2 occurrences
# No of times 35000: 4 occurrences
# No of times 53840: 2 occurrences
# No of times 49490: 2 occurrences
# No of times 3680: 3 occurrences
# No of times 39600: 2 occurrences
# No of times 54390: 2 occurrences
# No of times 2730: 3 occurrences
# No of times 46830: 2 occurrences
# No of times 26040: 2 occurrences
# No of times 2880: 2 occurrences
# No of times 24360: 2 occurrences
# No of times 46160: 3 occurrences
# No of times 38780: 2 occurrences
# No of times 26880: 2 occurrences
# No of times 51520: 2 occurrences
# No of times 30940: 2 occurrences
# No of times 40560: 2 occurrences
# No of times 42240: 2 occurrences
# No of times 32200: 2 occurrences
# No of times 6300: 2 occurrences
# No of times 28980: 2 occurrences
# No of times 59680: 2 occurrences
# No of times 50640: 2 occurrences
# No of times 21490: 2 occurrences
# No of times 3870: 2 occurrences
# No of times 43680: 2 occurrences
# No of times 36890: 2 occurrences
# No of times 40960: 2 occurrences
# No of times 47360: 2 occurrences
# No of times 72320: 2 occurrences
# --------------------------------------------------
#
# Column: auto_make
# ##################################################
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
# Total Unique value: 14
# #########################
# -------------------------
# Redundant values:
# No of times Saab: 80 occurrences
# No of times Mercedes: 65 occurrences
# No of times Dodge: 80 occurrences
# No of times Chevrolet: 76 occurrences
# No of times Accura: 68 occurrences
# No of times Nissan: 78 occurrences
# No of times Audi: 69 occurrences
# No of times Toyota: 70 occurrences
# No of times Ford: 72 occurrences
# No of times Suburu: 80 occurrences
# No of times BMW: 72 occurrences
# No of times Jeep: 67 occurrences
# No of times Honda: 55 occurrences
# No of times Volkswagen: 68 occurrences
# --------------------------------------------------
#
# Column: auto_model
# ##################################################
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# Legacy            32
# A5                32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# E400              27
# 95                27
# F150              27
# Grand Cherokee    25
# 93                25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# TL                20
# Impreza           20
# Corolla           20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
# Total Unique value: 39
# #########################
# -------------------------
# Redundant values:
# No of times 92x: 28 occurrences
# No of times E400: 27 occurrences
# No of times RAM: 43 occurrences
# No of times Tahoe: 24 occurrences
# No of times RSX: 12 occurrences
# No of times 95: 27 occurrences
# No of times Pathfinder: 31 occurrences
# No of times A5: 32 occurrences
# No of times Camry: 28 occurrences
# No of times F150: 27 occurrences
# No of times A3: 37 occurrences
# No of times Highlander: 22 occurrences
# No of times Neon: 37 occurrences
# No of times MDX: 36 occurrences
# No of times Maxima: 24 occurrences
# No of times Legacy: 32 occurrences
# No of times TL: 20 occurrences
# No of times Impreza: 20 occurrences
# No of times Forrestor: 28 occurrences
# No of times Escape: 24 occurrences
# No of times Corolla: 20 occurrences
# No of times 3 Series: 18 occurrences
# No of times C300: 18 occurrences
# No of times Wrangler: 42 occurrences
# No of times M5: 15 occurrences
# No of times X5: 23 occurrences
# No of times Civic: 22 occurrences
# No of times Passat: 33 occurrences
# No of times Silverado: 22 occurrences
# No of times CRV: 20 occurrences
# No of times 93: 25 occurrences
# No of times Accord: 13 occurrences
# No of times X6: 16 occurrences
# No of times Malibu: 30 occurrences
# No of times Fusion: 21 occurrences
# No of times Jetta: 35 occurrences
# No of times ML350: 20 occurrences
# No of times Ultima: 23 occurrences
# No of times Grand Cherokee: 25 occurrences
# --------------------------------------------------
#
# Column: auto_year
# ##################################################
# auto_year
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2009    50
# 2010    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: count, dtype: int64
# Total Unique value: 21
# #########################
# -------------------------
# Redundant values:
# No of times 2004: 39 occurrences
# No of times 2007: 52 occurrences
# No of times 2014: 44 occurrences
# No of times 2009: 50 occurrences
# No of times 2003: 51 occurrences
# No of times 2012: 46 occurrences
# No of times 2015: 47 occurrences
# No of times 1996: 37 occurrences
# No of times 2002: 49 occurrences
# No of times 2006: 53 occurrences
# No of times 2000: 42 occurrences
# No of times 2010: 50 occurrences
# No of times 1999: 55 occurrences
# No of times 2011: 53 occurrences
# No of times 2005: 54 occurrences
# No of times 2008: 45 occurrences
# No of times 1995: 56 occurrences
# No of times 2001: 42 occurrences
# No of times 1998: 40 occurrences
# No of times 1997: 46 occurrences
# No of times 2013: 49 occurrences
# --------------------------------------------------
#
# Column: fraud_reported
# ##################################################
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
# Total Unique value: 2
# #########################
# -------------------------
# Redundant values:
# No of times Y: 247 occurrences
# No of times N: 753 occurrences
# --------------------------------------------------
#
# Column: _c39
# ##################################################
# _c39
# NaN    1000
# Name: count, dtype: int64
# Total Unique value: 0
# #########################
# -------------------------
# Redundant values:
# --------------------------------------------------

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
df = df.drop(columns=['_c39'])

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
must_be_positive = [
    'months_as_customer', 'age', 'policy_annual_premium',
    'policy_deductable', 'umbrella_limit', 'capital-gains',
    'total_claim_amount', 'injury_claim', 'property_claim',
    'vehicle_claim', 'number_of_vehicles_involved',
    'bodily_injuries', 'witnesses'
]

invalid_mask = (df[must_be_positive] < 0).any(axis=1)
invalid_rows = df[invalid_mask]

print(f"Found {len(invalid_rows)} rows with invalid negative values.")
invalid_rows

df = df[~invalid_mask]
# Out:
# Found 1 rows with invalid negative values.

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
uniqueness_ratio = df.nunique() / len(df)

id_like_cols = uniqueness_ratio[uniqueness_ratio > 0.9].index.tolist()

print("Columns likely to be identifiers or with low predictive power:")
print(id_like_cols)

df = df.drop(columns=id_like_cols)
# Out:
# Columns likely to be identifiers or with low predictive power:
# ['policy_number', 'policy_bind_date', 'policy_annual_premium', 'insured_zip', 'incident_location']

# %%
# Check the dataset
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_state                 999 non-null    object
#  3   policy_csl                   999 non-null    object
#  4   policy_deductable            999 non-null    int64
#  5   umbrella_limit               999 non-null    int64
#  6   insured_sex                  999 non-null    object
#  7   insured_education_level      999 non-null    object
#  8   insured_occupation           999 non-null    object
#  9   insured_hobbies              999 non-null    object
#  10  insured_relationship         999 non-null    object
#  11  capital-gains                999 non-null    int64
#  12  capital-loss                 999 non-null    int64
#  13  incident_date                999 non-null    object
#  14  incident_type                999 non-null    object
#  15  collision_type               999 non-null    object
#  16  incident_severity            999 non-null    object
#  17  authorities_contacted        999 non-null    object
#  18  incident_state               999 non-null    object
#  19  incident_city                999 non-null    object
#  20  incident_hour_of_the_day     999 non-null    int64
#  21  number_of_vehicles_involved  999 non-null    int64
#  22  property_damage              999 non-null    object
#  23  bodily_injuries              999 non-null    int64
#  24  witnesses                    999 non-null    int64
#  25  police_report_available      999 non-null    object
#  26  total_claim_amount           999 non-null    int64
#  27  injury_claim                 999 non-null    int64
#  28  property_claim               999 non-null    int64
#  29  vehicle_claim                999 non-null    int64
#  30  auto_make                    999 non-null    object
#  31  auto_model                   999 non-null    object
#  32  auto_year                    999 non-null    int64
#  33  fraud_reported               999 non-null    object
# dtypes: int64(15), object(19)
# memory usage: 273.2+ KB
#    months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                 328   48           OH    250/500               1000
# 1                 228   42           IN    250/500               2000
# 2                 134   29           OH    100/300               2000
# 3                 256   41           IL    250/500               2000
# 4                 228   44           IL   500/1000               1000
#
#    umbrella_limit insured_sex insured_education_level insured_occupation  \
# 0               0        MALE                      MD       craft-repair
# 1         5000000        MALE                      MD  machine-op-inspct
# 2         5000000      FEMALE                     PhD              sales
# 3         6000000      FEMALE                     PhD       armed-forces
# 4         6000000        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    2015-01-25  Single Vehicle Collision   Side Collision      Major Damage
# 1    2015-01-21             Vehicle Theft                ?      Minor Damage
# 2    2015-02-22   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    2015-01-10  Single Vehicle Collision  Front Collision      Major Damage
# 4    2015-02-17             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  \
# 0                Police             SC      Columbus
# 1                Police             VA     Riverwood
# 2                Police             NY      Columbus
# 3                Police             OH     Arlington
# 4                Police             NY     Arlington
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported
# 0       2004              Y
# 1       2007              Y
# 2       2007              N
# 3       2014              Y
# 4       2009              N

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
df['incident_date'] = pd.to_datetime(df['incident_date'], errors='coerce')

# %%
# Check the features of the data again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_state                 999 non-null    object
#  3   policy_csl                   999 non-null    object
#  4   policy_deductable            999 non-null    int64
#  5   umbrella_limit               999 non-null    int64
#  6   insured_sex                  999 non-null    object
#  7   insured_education_level      999 non-null    object
#  8   insured_occupation           999 non-null    object
#  9   insured_hobbies              999 non-null    object
#  10  insured_relationship         999 non-null    object
#  11  capital-gains                999 non-null    int64
#  12  capital-loss                 999 non-null    int64
#  13  incident_date                999 non-null    datetime64[ns]
#  14  incident_type                999 non-null    object
#  15  collision_type               999 non-null    object
#  16  incident_severity            999 non-null    object
#  17  authorities_contacted        999 non-null    object
#  18  incident_state               999 non-null    object
#  19  incident_city                999 non-null    object
#  20  incident_hour_of_the_day     999 non-null    int64
#  21  number_of_vehicles_involved  999 non-null    int64
#  22  property_damage              999 non-null    object
#  23  bodily_injuries              999 non-null    int64
#  24  witnesses                    999 non-null    int64
#  25  police_report_available      999 non-null    object
#  26  total_claim_amount           999 non-null    int64
#  27  injury_claim                 999 non-null    int64
#  28  property_claim               999 non-null    int64
#  29  vehicle_claim                999 non-null    int64
#  30  auto_make                    999 non-null    object
#  31  auto_model                   999 non-null    object
#  32  auto_year                    999 non-null    int64
#  33  fraud_reported               999 non-null    object
# dtypes: datetime64[ns](1), int64(15), object(18)
# memory usage: 273.2+ KB

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = df.drop(columns=['fraud_reported'])
# Put the target variable in y
y = df['fraud_reported']

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_columns = X_train.select_dtypes(include=['number']).columns.tolist()
numerical_columns
# Out:
# ['months_as_customer',
#  'age',
#  'policy_deductable',
#  'umbrella_limit',
#  'capital-gains',
#  'capital-loss',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'bodily_injuries',
#  'witnesses',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_year']

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
plt.figure(figsize=(12, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot((len(numerical_columns) + 2) // 3, 3, i)
    sns.histplot(X_train[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
corr_matrix = X_train[numerical_columns].corr()
# Plot Heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
plt.title('Correlation Matrix of Numerical Column')
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6, 4))
ax = sns.countplot(x=y_train)
total = len(y_train)
for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.1f}%'
    ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom')
plt.title('Class Balance')
plt.xlabel('Target Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
def target_likelihood_analysis(X, y, target_positive='Y', plot=True):
    categorical_cols = X.select_dtypes(include=['object', 'category']).columns
    results = {}

    for col in categorical_cols:
        likelihood_df = (
            pd.DataFrame({col: X[col], 'target': y})
            .groupby(col)['target']
            .apply(lambda x: (x == target_positive).mean())
            .reset_index()
            .rename(columns={'target': 'likelihood_Y'})
        )
        results[col] = likelihood_df

        if plot:
            plt.figure(figsize=(6,4))
            sns.barplot(data=likelihood_df, x=col, y='likelihood_Y', palette="viridis")
            plt.title(f"Target Likelihood for '{col}' (P(target='{target_positive}'))", fontsize=14)
            plt.ylabel("Likelihood of Y")
            plt.ylim(0, 1)
            plt.xticks(rotation=45)
            plt.show()

    return results

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
target = 'fraud_reported'
plt.figure(figsize=(10, 3 * len(numerical_columns)))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 1, i)
    sns.boxplot(data=df, x=target, y=col)
    plt.title(f"Relationship between {col} and {target}", fontsize=14)
    plt.xlabel(target)
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns
numerical_columns = X_test.select_dtypes(include=['number']).columns.tolist()
numerical_columns
# Out:
# ['months_as_customer',
#  'age',
#  'policy_deductable',
#  'umbrella_limit',
#  'capital-gains',
#  'capital-loss',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'bodily_injuries',
#  'witnesses',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_year']

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution
plt.figure(figsize=(12, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot((len(numerical_columns) + 2) // 3, 3, i)
    sns.histplot(X_train[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

print("Original Class Distribution:")
print(y_train.value_counts())
print("\nResampled Class Distribution:")
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Original Class Distribution:
# fraud_reported
# N    526
# Y    173
# Name: count, dtype: int64
#
# Resampled Class Distribution:
# fraud_reported
# N    526
# Y    526
# Name: count, dtype: int64

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data
numerical_columns = X_train_resampled.select_dtypes(include=['number']).columns
categorical_columns = X_train_resampled.select_dtypes(include=['object', 'category']).columns
datetime_columns = X_train_resampled.select_dtypes(include=['datetime']).columns
X_train_final = X_train_resampled.copy()
X_test_final = X_test.copy()
X_train_final['year'] = X_train_final['incident_date'].dt.year
X_train_final['month'] = X_train_final['incident_date'].dt.month
X_train_final['day'] = X_train_final['incident_date'].dt.day
X_test_final['year'] = X_test_final['incident_date'].dt.year
X_test_final['month'] = X_test_final['incident_date'].dt.month
X_test_final['day'] = X_test_final['incident_date'].dt.day

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
numeric_train = X_train_final.select_dtypes(include=['number'])
corr_matrix = numeric_train.corr().abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop_corr = [col for col in upper.columns if any(upper[col] > 0.85)]
print(f"Columns dropped due to high correlation: {to_drop_corr} : {['incident_date']}")
X_train_final.drop(columns=to_drop_corr, inplace=True, errors='ignore')
X_test_final.drop(columns=to_drop_corr, inplace=True, errors='ignore')
X_train_final.drop(columns=['incident_date'], inplace=True, errors='ignore')
X_test_final.drop(columns=['incident_date'], inplace=True, errors='ignore')
# Out:
# Columns dropped due to high correlation: ['age', 'vehicle_claim'] : ['incident_date']

# %%
# Check the data
X_train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1052 non-null   int64
#  1   policy_state                 1052 non-null   object
#  2   policy_csl                   1052 non-null   object
#  3   policy_deductable            1052 non-null   int64
#  4   umbrella_limit               1052 non-null   int64
#  5   insured_sex                  1052 non-null   object
#  6   insured_education_level      1052 non-null   object
#  7   insured_occupation           1052 non-null   object
#  8   insured_hobbies              1052 non-null   object
#  9   insured_relationship         1052 non-null   object
#  10  capital-gains                1052 non-null   int64
#  11  capital-loss                 1052 non-null   int64
#  12  incident_type                1052 non-null   object
#  13  collision_type               1052 non-null   object
#  14  incident_severity            1052 non-null   object
#  15  authorities_contacted        1052 non-null   object
#  16  incident_state               1052 non-null   object
#  17  incident_city                1052 non-null   object
#  18  incident_hour_of_the_day     1052 non-null   int64
#  19  number_of_vehicles_involved  1052 non-null   int64
#  20  property_damage              1052 non-null   object
#  21  bodily_injuries              1052 non-null   int64
#  22  witnesses                    1052 non-null   int64
#  23  police_report_available      1052 non-null   object
#  24  total_claim_amount           1052 non-null   int64
#  25  injury_claim                 1052 non-null   int64
#  26  property_claim               1052 non-null   int64
#  27  auto_make                    1052 non-null   object
#  28  auto_model                   1052 non-null   object
#  29  auto_year                    1052 non-null   int64
#  30  year                         1052 non-null   int32
#  31  month                        1052 non-null   int32
#  32  day                          1052 non-null   int32
# dtypes: int32(3), int64(13), object(17)
# memory usage: 259.0+ KB

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
threshold = 0.05
for col in categorical_columns:
  freq = X_train_final[col].value_counts(normalize=True)
  rare_category = freq[freq < threshold].index.tolist()
  X_train_final[col] = X_train_final[col].replace(rare_category, 'Other')
  X_test_final[col] = X_test_final[col].replace(rare_category, 'Other')
  print(f"Column '{col}': replaced {len(rare_category)} rare categories with 'Other'")
# Out:
# Column 'policy_state': replaced 0 rare categories with 'Other'
# Column 'policy_csl': replaced 0 rare categories with 'Other'
# Column 'insured_sex': replaced 0 rare categories with 'Other'
# Column 'insured_education_level': replaced 0 rare categories with 'Other'
# Column 'insured_occupation': replaced 2 rare categories with 'Other'
# Column 'insured_hobbies': replaced 12 rare categories with 'Other'
# Column 'insured_relationship': replaced 0 rare categories with 'Other'
# Column 'incident_type': replaced 0 rare categories with 'Other'
# Column 'collision_type': replaced 0 rare categories with 'Other'
# Column 'incident_severity': replaced 0 rare categories with 'Other'
# Column 'authorities_contacted': replaced 0 rare categories with 'Other'
# Column 'incident_state': replaced 2 rare categories with 'Other'
# Column 'incident_city': replaced 0 rare categories with 'Other'
# Column 'property_damage': replaced 0 rare categories with 'Other'
# Column 'police_report_available': replaced 0 rare categories with 'Other'
# Column 'auto_make': replaced 1 rare categories with 'Other'
# Column 'auto_model': replaced 39 rare categories with 'Other'

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_column = X_train_final.select_dtypes(include=['object', 'category']).columns.tolist()
print("Categorical column for creating dummy variable :: \n",categorical_column)
# Out:
# Categorical column for creating dummy variable ::
#  ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
training_df = pd.get_dummies(X_train_final, columns=categorical_column, drop_first=True)

print("Shape of training data after creating dummy variables :: ", training_df.shape)
# Out:
# Shape of training data after creating dummy variables ::  (1052, 92)

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
validation_df = pd.get_dummies(X_test_final, columns=categorical_column, drop_first=True)
validation_df = validation_df.reindex(columns=training_df.columns, fill_value=0)
print("Shape of validation data after creating dummy variables :: ", validation_df.shape)
# Out:
# Shape of validation data after creating dummy variables ::  (300, 92)

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
training_df_dummy = training_df.copy()
training_df_dummy['fraud_reported'] = y_train_resampled
training_df_dummy['fraud_reported'] = training_df_dummy['fraud_reported'].map({'Y': 1, 'N': 0})
# Create dummy variable for dependent feature in validation data
validation_df_dummy = validation_df.copy()
validation_df_dummy['fraud_reported'] = y_test
validation_df_dummy['fraud_reported'] = validation_df_dummy['fraud_reported'].map({'Y': 1, 'N': 0})

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler
# Scale the numeric features present in the training data
target_col = 'fraud_reported'
numerical_columns = training_df_dummy.select_dtypes(include=['number']).columns.tolist()
if target_col in numerical_columns:
    numerical_columns.remove(target_col)
scaler = StandardScaler()
training_df_dummy[numerical_columns] = scaler.fit_transform(training_df_dummy[numerical_columns])
# Scale the numeric features present in the validation data
validation_df_dummy[numerical_columns] = scaler.transform(validation_df_dummy[numerical_columns])

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Apply RFECV to identify the most relevant features
X_rfecv = training_df_dummy.drop(columns=['fraud_reported'])
y_rfecv = training_df_dummy['fraud_reported']

logreg = LogisticRegression(max_iter=1000, solver='liblinear', class_weight='balanced', random_state=42)

rfecv = RFECV(estimator=logreg, step=1, cv=StratifiedKFold(5, shuffle=True, random_state=42), scoring='roc_auc', min_features_to_select=5)
rfecv.fit(X_rfecv, y_rfecv)

print(f"Optimal number of features: {rfecv.n_features_}")

selected_features = X_rfecv.columns[rfecv.support_]
print("Selected Features: \n", list(selected_features))
# Out:
# Optimal number of features: 43
# Selected Features:
#  ['umbrella_limit', 'witnesses', 'policy_state_OH', 'policy_csl_250/500', 'policy_csl_500/1000', 'insured_education_level_JD', 'insured_education_level_MD', 'insured_education_level_PhD', 'insured_occupation_adm-clerical', 'insured_occupation_armed-forces', 'insured_occupation_craft-repair', 'insured_occupation_exec-managerial', 'insured_occupation_farming-fishing', 'insured_occupation_machine-op-inspct', 'insured_occupation_priv-house-serv', 'insured_occupation_prof-specialty', 'insured_occupation_sales', 'insured_occupation_tech-support', 'insured_occupation_transport-moving', 'insured_hobbies_bungie-jumping', 'insured_hobbies_chess', 'insured_hobbies_skydiving', 'insured_hobbies_yachting', 'insured_relationship_not-in-family', 'insured_relationship_other-relative', 'insured_relationship_own-child', 'insured_relationship_unmarried', 'collision_type_Front Collision', 'collision_type_Rear Collision', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage', 'authorities_contacted_Other', 'incident_state_NY', 'incident_state_VA', 'incident_state_WV', 'incident_city_Northbrook', 'property_damage_NO', 'auto_make_Audi', 'auto_make_BMW', 'auto_make_Dodge', 'auto_make_Nissan', 'auto_make_Other']

# %%
# Display the features ranking by RFECV in a DataFrame
feature_ranking_df = pd.DataFrame({'Feature': X_rfecv.columns, 'Ranking': rfecv.ranking_}).sort_values(by='Ranking')
feature_ranking_df.head(10)
# Out:
#                                Feature  Ranking
# 2                       umbrella_limit        1
# 8                            witnesses        1
# 27     insured_occupation_adm-clerical        1
# 28     insured_occupation_armed-forces        1
# 23          insured_education_level_JD        1
# 31  insured_occupation_farming-fishing        1
# 29     insured_occupation_craft-repair        1
# 30  insured_occupation_exec-managerial        1
# 24          insured_education_level_MD        1
# 26         insured_education_level_PhD        1

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = X_rfecv.columns[rfecv.support_].tolist()
print(f"Number of selected features: {len(col)}")
print("Selected features: \n",col)
# Out:
# Number of selected features: 43
# Selected features:
#  ['umbrella_limit', 'witnesses', 'policy_state_OH', 'policy_csl_250/500', 'policy_csl_500/1000', 'insured_education_level_JD', 'insured_education_level_MD', 'insured_education_level_PhD', 'insured_occupation_adm-clerical', 'insured_occupation_armed-forces', 'insured_occupation_craft-repair', 'insured_occupation_exec-managerial', 'insured_occupation_farming-fishing', 'insured_occupation_machine-op-inspct', 'insured_occupation_priv-house-serv', 'insured_occupation_prof-specialty', 'insured_occupation_sales', 'insured_occupation_tech-support', 'insured_occupation_transport-moving', 'insured_hobbies_bungie-jumping', 'insured_hobbies_chess', 'insured_hobbies_skydiving', 'insured_hobbies_yachting', 'insured_relationship_not-in-family', 'insured_relationship_other-relative', 'insured_relationship_own-child', 'insured_relationship_unmarried', 'collision_type_Front Collision', 'collision_type_Rear Collision', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage', 'authorities_contacted_Other', 'incident_state_NY', 'incident_state_VA', 'incident_state_WV', 'incident_city_Northbrook', 'property_damage_NO', 'auto_make_Audi', 'auto_make_BMW', 'auto_make_Dodge', 'auto_make_Nissan', 'auto_make_Other']

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
col_by_rfecv = X_rfecv.columns[rfecv.support_].tolist()

# %%
# Import statsmodels and add constant
import statsmodels.api as sm
X_rfecv_constant = X_rfecv[col_by_rfecv].copy()
bool_cols = X_rfecv_constant.select_dtypes(include='bool').columns
if len(bool_cols) > 0:
    X_rfecv_constant[bool_cols] = X_rfecv_constant[bool_cols].astype(int)
    print(f"\nConverted {len(bool_cols)} boolean columns to 0/1")
X_rfecv_constant = sm.add_constant(X_rfecv_constant)
# Check the
X_rfecv_constant.info()
# Out:
# Converted 41 boolean columns to 0/1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 44 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0
# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
X_vif = X_rfecv_constant
vif_data = pd.DataFrame()
vif_data["feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]
print("VIF :: \n", vif_data)
# Out:
# VIF ::
#                                   feature        VIF
# 0                                  const  18.598454
# 1                         umbrella_limit   1.115080
# 2                              witnesses   1.095291
# 3                        policy_state_OH   1.084156
# 4                     policy_csl_250/500   1.412014
# 5                    policy_csl_500/1000   1.403936
# 6             insured_education_level_JD   1.206489
# 7             insured_education_level_MD   1.190618
# 8            insured_education_level_PhD   1.164470
# 9        insured_occupation_adm-clerical   1.481426
# 10       insured_occupation_armed-forces   1.468641
# 11       insured_occupation_craft-repair   1.538530
# 12    insured_occupation_exec-managerial   1.607594
# 13    insured_occupation_farming-fishing   1.363476
# 14  insured_occupation_machine-op-inspct   1.562082
# 15    insured_occupation_priv-house-serv   1.396265
# 16     insured_occupation_prof-specialty   1.523132
# 17              insured_occupation_sales   1.504562
# 18       insured_occupation_tech-support   1.510611
# 19   insured_occupation_transport-moving   1.541714
# 20        insured_hobbies_bungie-jumping   1.101495
# 21                 insured_hobbies_chess   1.186471
# 22             insured_hobbies_skydiving   1.187879
# 23              insured_hobbies_yachting   1.076371
# 24    insured_relationship_not-in-family   1.422449
# 25   insured_relationship_other-relative   1.400125
# 26        insured_relationship_own-child   1.313185
# 27        insured_relationship_unmarried   1.381080
# 28        collision_type_Front Collision   1.413880
# 29         collision_type_Rear Collision   1.443814
# 30        incident_severity_Minor Damage   1.378678
# 31          incident_severity_Total Loss   1.365228
# 32      incident_severity_Trivial Damage   1.267738
# 33           authorities_contacted_Other   1.138550
# 34                     incident_state_NY   1.267605
# 35                     incident_state_VA   1.234985
# 36                     incident_state_WV   1.329504
# 37              incident_city_Northbrook   1.070875
# 38                    property_damage_NO   1.116931
# 39                        auto_make_Audi   1.176803
# 40                         auto_make_BMW   1.132866
# 41                       auto_make_Dodge   1.127219
# 42                      auto_make_Nissan   1.158198
# 43                       auto_make_Other   1.094229

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
traning_prob = result.predict(X_rfecv_constant)
# Reshape it into an array
training_prob_array = traning_prob.values.reshape(-1, 1)

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
result_df = pd.DataFrame({'Actual_Fraud': y_rfecv, 'Predicted_Probability': training_prob_array.flatten()})
# Create new column indicating predicted classifications based on a cutoff value of 0.5
result_df['Predicted_Classification'] = (result_df['Predicted_Probability'] >= 0.5).astype(int)
result_df.head()
# Out:
#    Actual_Fraud  Predicted_Probability  Predicted_Classification
# 0             0               0.809455                         1
# 1             0               0.110734                         0
# 2             0               0.057883                         0
# 3             0               0.025999                         0
# 4             0               0.112183                         0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model
accuracy_score = metrics.accuracy_score(result_df['Actual_Fraud'], result_df['Predicted_Classification'])
print(f"Accuracy: {accuracy_score}")
# Out:
# Accuracy: 0.8669201520912547

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
confusion_matrix = metrics.confusion_matrix(result_df['Actual_Fraud'], result_df['Predicted_Classification'])
print("Confusion Matrix: \n", confusion_matrix)
# Out:
# Confusion Matrix:
#  [[453  73]
#  [ 67 459]]

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn , fp, fn, tp = confusion_matrix.ravel()
print("True Negative: ", tn)
print("False Positive: ", fp)
print("False Negative: ", fn)
print("True Positive: ", tp)
# Out:
# True Negative:  453
# False Positive:  73
# False Negative:  67
# True Positive:  459

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity: ", sensitivity)

# Calculate the specificity
specificity = tn / (tn + fp)
print("Specificity: ", specificity)

# Calculate Precision
precision = tp / (tp + fp)
print("Precision: ", precision)

# Calculate Recall
recall =  tp / (tp + fn)
print("Recall: ", recall)

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print("F1 Score: ", f1_score)
# Out:
# Sensitivity:  0.8726235741444867
# Specificity:  0.8612167300380228
# Precision:  0.8627819548872181
# Recall:  0.8726235741444867
# F1 Score:  0.8676748582230625

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, auc

# Define ROC function
def plot_roc_curve(y_true, y_pred):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f})', lw=2)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Guess')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %%
# Call the ROC function
plot_roc_curve(result_df['Actual_Fraud'], result_df['Predicted_Probability'])

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
cutoffs = [i/10 for i in range(1, 10)]

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
metrics_list = []
for cutoff in cutoffs:
    result_df[f'pred_{cutoffs}'] = (result_df['Predicted_Probability'] >= cutoff).astype(int)

    TP = ((result_df[f'pred_{cutoffs}'] == 1) & (result_df['Actual_Fraud'] == 1)).sum()
    TN = ((result_df[f'pred_{cutoffs}'] == 0) & (result_df['Actual_Fraud'] == 0)).sum()
    FP = ((result_df[f'pred_{cutoffs}'] == 1) & (result_df['Actual_Fraud'] == 0)).sum()
    FN = ((result_df[f'pred_{cutoffs}'] == 0) & (result_df['Actual_Fraud'] == 1)).sum()

    accuracy = (TP + TN) / (TP + TN + FP + FN)
    sensitivity = TP / (TP + FN)
    specificity = TN / (TN + FP)
    metrics_list.append({'Cutoff': cutoff, 'Accuracy': accuracy, 'Sensitivity': sensitivity, 'Specificity': specificity})

metrics_df = pd.DataFrame(metrics_list)

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(10, 6))
plt.plot(metrics_df['Cutoff'], metrics_df['Accuracy'], label='Accuracy')
plt.plot(metrics_df['Cutoff'], metrics_df['Sensitivity'], label='Sensitivity')
plt.plot(metrics_df['Cutoff'], metrics_df['Specificity'], label='Specificity')
plt.xlabel('Probability Cutoff')
plt.ylabel('Metric Value')
plt.title('Model Performance Metrics at Different Probability Cutoffs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
optimal_cutoff = 0.55
result_df['Final_Prediction'] = (result_df['Predicted_Probability'] >= optimal_cutoff).astype(int)

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
accuracy = metrics.accuracy_score(result_df['Actual_Fraud'], result_df['Final_Prediction'])
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.879277566539924

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
confusion_matrix = metrics.confusion_matrix(result_df['Actual_Fraud'], result_df['Final_Prediction'])
print("Confusion Matrix: \n", confusion_matrix)
# Out:
# Confusion Matrix:
#  [[466  60]
#  [ 67 459]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = confusion_matrix.ravel()
print("True Negative: ", tn)
print("False Positive: ", fp)
print("False Negative: ", fn)
print("True Positive: ", tp)
# Out:
# True Negative:  466
# False Positive:  60
# False Negative:  67
# True Positive:  459

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity: ", sensitivity)

# Calculate the specificity
specificity = tn / (tn + fp)
print("Specificity: ", specificity)

# Calculate Precision
precision = tp / (tp + fp)
print("Precision: ", precision)

# Calculate Recall
recall =  sensitivity
print("Recall: ", recall)

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print("F1 Score: ", f1_score)
# Out:
# Sensitivity:  0.8726235741444867
# Specificity:  0.8859315589353612
# Precision:  0.884393063583815
# Recall:  0.8726235741444867
# F1 Score:  0.8784688995215311

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
precision, recall, thresholds = precision_recall_curve(result_df['Actual_Fraud'], result_df['Predicted_Probability'])
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label='Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_rfecv_constant, y_rfecv)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
importance_score = rf_model.feature_importances_
# Create a DataFrame to visualise the importance scores
feature_importance_df = pd.DataFrame({'Feature': X_rfecv_constant.columns, 'Importance': importance_score})
feature_importance_df.sort_values(by='Importance', ascending=False, inplace=True)
feature_importance_df
# Out:
#                                  Feature  Importance
# 30        incident_severity_Minor Damage    0.129818
# 21                 insured_hobbies_chess    0.085115
# 31          incident_severity_Total Loss    0.077704
# 2                              witnesses    0.048884
# 32      incident_severity_Trivial Damage    0.042676
# 1                         umbrella_limit    0.036350
# 38                    property_damage_NO    0.027926
# 36                     incident_state_WV    0.027695
# 3                        policy_state_OH    0.024897
# 28        collision_type_Front Collision    0.024682
# 4                     policy_csl_250/500    0.023952
# 5                    policy_csl_500/1000    0.022861
# 29         collision_type_Rear Collision    0.022149
# 34                     incident_state_NY    0.021900
# 33           authorities_contacted_Other    0.021040
# 25   insured_relationship_other-relative    0.019196
# 26        insured_relationship_own-child    0.018632
# 7             insured_education_level_MD    0.018179
# 27        insured_relationship_unmarried    0.017846
# 6             insured_education_level_JD    0.017803
# 24    insured_relationship_not-in-family    0.016585
# 39                        auto_make_Audi    0.015723
# 8            insured_education_level_PhD    0.015334
# 12    insured_occupation_exec-managerial    0.015122
# 41                       auto_make_Dodge    0.014649
# 19   insured_occupation_transport-moving    0.014292
# 10       insured_occupation_armed-forces    0.014241
# 16     insured_occupation_prof-specialty    0.014116
# 37              incident_city_Northbrook    0.013911
# 35                     incident_state_VA    0.013686
# 18       insured_occupation_tech-support    0.012375
# 42                      auto_make_Nissan    0.010936
# 11       insured_occupation_craft-repair    0.010761
# 14  insured_occupation_machine-op-inspct    0.010680
# 15    insured_occupation_priv-house-serv    0.010105
# 40                         auto_make_BMW    0.009942
# 17              insured_occupation_sales    0.009551
# 9        insured_occupation_adm-clerical    0.009536
# 43                       auto_make_Other    0.008955
# 13    insured_occupation_farming-fishing    0.008633
# 22             insured_hobbies_skydiving    0.007378
# 20        insured_hobbies_bungie-jumping    0.007180
# 23              insured_hobbies_yachting    0.007003
# 0                                  const    0.000000

# %%
# Select features with high importance scores
selected_features = feature_importance_df[feature_importance_df['Importance'] > 0.005]['Feature'].tolist()
print("Selected Features: \n", selected_features)
# Create a new training data with only the selected features
X_train_final_rf = X_rfecv_constant[selected_features]
X_test_final_rf = validation_df_dummy[selected_features]
# Out:
# Selected Features:
#  ['incident_severity_Minor Damage', 'insured_hobbies_chess', 'incident_severity_Total Loss', 'witnesses', 'incident_severity_Trivial Damage', 'umbrella_limit', 'property_damage_NO', 'incident_state_WV', 'policy_state_OH', 'collision_type_Front Collision', 'policy_csl_250/500', 'policy_csl_500/1000', 'collision_type_Rear Collision', 'incident_state_NY', 'authorities_contacted_Other', 'insured_relationship_other-relative', 'insured_relationship_own-child', 'insured_education_level_MD', 'insured_relationship_unmarried', 'insured_education_level_JD', 'insured_relationship_not-in-family', 'auto_make_Audi', 'insured_education_level_PhD', 'insured_occupation_exec-managerial', 'auto_make_Dodge', 'insured_occupation_transport-moving', 'insured_occupation_armed-forces', 'insured_occupation_prof-specialty', 'incident_city_Northbrook', 'incident_state_VA', 'insured_occupation_tech-support', 'auto_make_Nissan', 'insured_occupation_craft-repair', 'insured_occupation_machine-op-inspct', 'insured_occupation_priv-house-serv', 'auto_make_BMW', 'insured_occupation_sales', 'insured_occupation_adm-clerical', 'auto_make_Other', 'insured_occupation_farming-fishing', 'insured_hobbies_skydiving', 'insured_hobbies_bungie-jumping', 'insured_hobbies_yachting']

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_model.fit(X_train_final_rf, y_rfecv)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_pred_rf = rf_model.predict(X_train_final_rf)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
train_accuracy = metrics.accuracy_score(y_rfecv, y_train_pred_rf)
print(f"Accuracy: {train_accuracy}")
# Out:
# Accuracy: 1.0

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
confusion_matrix = metrics.confusion_matrix(y_rfecv, y_train_pred_rf)
print("Confusion Matrix: \n", confusion_matrix)
# Out:
# Confusion Matrix:
#  [[526   0]
#  [  0 526]]

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = confusion_matrix.ravel()
print("True Negative: ", tn)
print("False Positive: ", fp)
print("False Negative: ", fn)
print("True Positive: ", tp)
# Out:
# True Negative:  526
# False Positive:  0
# False Negative:  0
# True Positive:  526

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity: ", sensitivity)

# Calculate the specificity
specificity = tn / (tn + fp)
print("Specificity: ", specificity)

# Calculate Precision
precision = tp / (tp + fp)
print("Precision: ", precision)

# Calculate Recall
recall =  sensitivity
print("Recall: ", recall)

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print("F1 Score: ", f1_score)
# Out:
# Sensitivity:  1.0
# Specificity:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 Score:  1.0

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
cross_val_scores = cross_val_score(rf_model, X_train_final_rf, y_rfecv, cv=5, scoring='accuracy')
print("Cross Validation Scores: \n", cross_val_scores)
# Out:
# Cross Validation Scores:
#  [0.90047393 0.96208531 0.97142857 0.94285714 0.94285714]

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values
rf = RandomForestClassifier(random_state=42)
param_grid = {
    'n_estimators': [50,100,200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, scoring='accuracy')
grid_search.fit(X_train_final_rf, y_rfecv)
# Best Hyperparameters
best_param = grid_search.best_params_
print("Best Hyperparameters: \n", best_param)
print("CV score: \n", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best Hyperparameters:
#  {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# CV score:
#  0.9448973143759873

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
rf_best = RandomForestClassifier(n_estimators=best_param['n_estimators'],
                                 max_depth=best_param['max_depth'],
                                 min_samples_split=best_param['min_samples_split'],
                                 min_samples_leaf=best_param['min_samples_leaf'],
                                 max_features=best_param['max_features'],
                                 random_state=42)
rf_best.fit(X_train_final_rf, y_rfecv)
# Out:
# RandomForestClassifier(max_depth=20, max_features='log2', n_estimators=200,
#                        random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
y_train_pred_rf_best = rf_best.predict(X_train_final_rf)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
train_accuracy = metrics.accuracy_score(y_rfecv, y_train_pred_rf_best)
print(f"Accuracy: {train_accuracy}")
# Out:
# Accuracy: 0.9990494296577946

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_rfecv, y_train_pred_rf_best)
print("Confusion Matrix: \n", confusion_matrix)
# Out:
# Confusion Matrix:
#  [[525   1]
#  [  0 526]]

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = confusion_matrix.ravel()
print("True Negative: ", tn)
print("False Positive: ", fp)
print("False Negative: ", fn)
print("True Positive: ", tp)
# Out:
# True Negative:  525
# False Positive:  1
# False Negative:  0
# True Positive:  526

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity: ", sensitivity)

# Calculate the specificity
specificity = tn / (tn + fp)
print("Specificity: ", specificity)

# Calculate Precision
precision = tp / (tp + fp)
print("Precision: ", precision)

# Calculate Recall
recall =  sensitivity
print("Recall: ", recall)

# Calculate F1-Score
f1_score = 2 * (precision * recall) / (precision + recall)
print("F1 Score: ", f1_score)
# Out:
# Sensitivity:  1.0
# Specificity:  0.9980988593155894
# Precision:  0.9981024667931688
# Recall:  1.0
# F1 Score:  0.9990503323836657

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
validation_df_dummy = validation_df[selected_features]
# Add constant to X_validation
X_validation_constant = sm.add_constant(validation_df_dummy)

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
X_validation_constant = X_validation_constant.astype(float)
y_validation_pred = result.predict(X_validation_constant)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
validation_result = pd.DataFrame({'Actual_Fraud': y_test, 'Predicted_Probability': y_validation_pred})

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
validation_result['Predicted_Classification'] = (validation_result['Predicted_Probability'] >= 0.5).astype(int)

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
accuracy = metrics.accuracy_score(validation_result['Actual_Fraud'].map({'Y': 1, 'N': 0}), validation_result['Predicted_Classification'])
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.31333333333333335

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
confusion_matrix = metrics.confusion_matrix(validation_result['Actual_Fraud'].map({'Y': 1, 'N': 0}), validation_result['Predicted_Classification'])
print("Confusion Matrix: \n", confusion_matrix)
# Out:
# Confusion Matrix:
#  [[ 23 203]
#  [  3  71]]

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tp, fp, fn, tn = confusion_matrix.ravel()
print("True Negative: ", tn)
print("False Positive: ", fp)
print("False Negative: ", fn)
print("True Positive: ", tp)
# Out:
# True Negative:  71
# False Positive:  203
# False Negative:  3
# True Positive:  23

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity: ", sensitivity)

# Calculate the specificity
specificity = tn / (tn + fp)
print("Specificity: ", specificity)

# Calculate Precision
precision = tp / (tp + fp)
print("Precision: ", precision)

# Calculate Recall
recall =  sensitivity
print("Recall: ", recall)

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print("F1 Score: ", f1_score)
# Out:
# Sensitivity:  0.8846153846153846
# Specificity:  0.2591240875912409
# Precision:  0.10176991150442478
# Recall:  0.8846153846153846
# F1 Score:  0.18253968253968253

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data
X_validation = validation_df[selected_features]
# Make predictions on the validation data
y_val_pred_prob = rf_model.predict_proba(X_validation)[:, 1]

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
accuracy = metrics.accuracy_score(y_test.map({'Y': 1, 'N': 0}), (y_val_pred_prob >= 0.5).astype(int))
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.78

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test.map({'Y': 1, 'N': 0}), (y_val_pred_prob >= 0.5).astype(int))
print("Confusion Matrix: \n", confusion_matrix)
# Out:
# Confusion Matrix:
#  [[195  31]
#  [ 35  39]]

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = confusion_matrix.ravel()
print("True Negative: ", tn)
print("False Positive: ", fp)
print("False Negative: ", fn)
print("True Positive: ", tp)
# Out:
# True Negative:  195
# False Positive:  31
# False Negative:  35
# True Positive:  39

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity: ", sensitivity)

# Calculate the specificity
specificity = tn / (tn + fp)
print("Specificity: ", specificity)

# Calculate Precision
precision = tp / (tp + fp)
print("Precision: ", precision)

# Calculate Recall
recall =  sensitivity
print("Recall: ", recall)

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print("F1 Score: ", f1_score)
# Out:
# Sensitivity:  0.527027027027027
# Specificity:  0.8628318584070797
# Precision:  0.5571428571428572
# Recall:  0.527027027027027
# F1 Score:  0.5416666666666666

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.

# %% [markdown]
# **Pattern Analysis – How can we detect fraud indicators in historical claims?**
# We can analyze historical claim data to detect patterns by performing Exploratory Data Analysis (EDA). This involves:
# *   Univariate Analysis: Examining the distribution of individual features (both numerical and categorical) to understand their characteristics and identify any unusual patterns.
# *   Correlation Analysis: Investigating the relationships between numerical features to identify potential dependencies.
# *   Bivariate Analysis: Exploring the relationships between features and the target
# variable (fraud_reported) to understand how different feature values influence the likelihood of a claim being fraudulent. This is done for both numerical and categorical features.
#
#
# **Predictive Features – Which factors best predict fraud?**
# Based on the Random Forest model's feature importance scores, the most predictive features of fraudulent behavior are:
# *   incident_severity_Minor Damage
# *   insured_hobbies_chess
# *   incident_severity_Total Loss
# *   witnesses
# *   incident_severity_Trivial Damage
# *   umbrella_limit
# *   property_damage_NO
# *   incident_state_WV
# *   policy_state_OH
# *   collision_type_Front Collision
# *   policy_csl_250/500
# *   policy_csl_500/1000
# *   collision_type_Rear Collision
# *   incident_state_NY
# *   authorities_contacted_Other
# *   insured_relationship_other-relative
# *   insured_relationship_own-child
# *   insured_education_level_MD
# *   insured_relationship_unmarried
# *   insured_education_level_JD
# *   insured_relationship_not-in-family
# *   auto_make_Audi
# *   insured_education_level_PhD
# *   insured_occupation_exec-managerial
# *   auto_make_Dodge
# *   insured_occupation_transport-moving
# *   insured_occupation_armed-forces
# *   insured_occupation_prof-specialty
# *   incident_city_Northbrook
# *   incident_state_VA
# *   insured_occupation_tech-support
# *   auto_make_Nissan
# *   insured_occupation_craft-repair
# *   insured_occupation_machine-op-inspct
# *   insured_occupation_priv-house-serv
# *   auto_make_BMW
# *   insured_occupation_sales
# *   insured_occupation_adm-clerical
# *   auto_make_Other
# *   insured_occupation_farming-fishing
# *   insured_hobbies_skydiving
# *   insured_hobbies_bungie-jumping
# *   insured_hobbies_yachting
#
# **Fraud Likelihood – Can we score new claims for fraud risk before approval?**
# *   We can predict the likelihood of fraud for an incoming claim based on past data.
# *   By training machine learning models (like Logistic Regression and Random Forest) on the historical claim data, we can use these models to predict the probability of an incoming claim being fraudulent.
# *   The models learn patterns and relationships from the historical data that are indicative of fraudulent behavior.
#
# **Actionable Insights – How can the model improve fraud detection?**
# *   Focus on key features: The most important features identified by the models (e.g., incident severity, insured hobbies, number of witnesses, umbrella limit, etc.) should be prioritized in the manual review process. Claims with suspicious values or combinations of these features should be flagged for closer inspection.
# *   Automated flagging: The trained model can be used to automatically flag claims with a high predicted probability of fraud. This can help streamline the initial screening process and reduce the workload on manual reviewers.
# *   Identify unusual patterns: The analysis of feature importance and the relationships between features and the target variable can help identify unusual patterns or anomalies that may indicate fraudulent activity. These patterns can be used to refine fraud detection rules or develop new fraud indicators.
# *   Continuous monitoring and retraining: The model should be continuously monitored for performance and retrained periodically with new data to adapt to evolving fraud patterns.
#
# In conclusion, the Random Forest model performed better in this analysis and can be used to predict the likelihood of fraud for incoming claims. The insights gained from the model, particularly the important features, can significantly help Global Insure improve their fraud detection process by enabling more efficient and data-driven screening of claims.
